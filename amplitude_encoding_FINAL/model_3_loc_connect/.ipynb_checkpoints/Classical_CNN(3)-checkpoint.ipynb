# %%
#libraries

import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import sympy
import numpy as np
#import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
# Out:
# 2023-07-07 15:48:17.510869: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-07 15:48:17.510897: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-07 15:48:21.143546: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-07 15:48:21.143591: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (marco-Lenovo-S340-15IWL): /proc/driver/nvidia/version does not exist
# 2023-07-07 15:48:21.143877: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Import the data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# # Filter the 3 and 6 labels

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
print(y_train[0])

plt.imshow(x_train[0, :, :, 0])
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Rescale the image

# %%
x_train_small = tf.image.resize(x_train, (8,8)).numpy()
x_test_small = tf.image.resize(x_test, (8,8)).numpy()
x_train_small = x_train_small[0:5000]
x_test_small = x_test_small[0:500]
y_train = y_train[0:5000]
y_test = y_test[0:500]
# Out:
# 2023-07-07 15:48:30.008014: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 75571328 exceeds 10% of free system memory.

# %%
print(y_train[0])

plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1)
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Classical Convolutional Neural Network

# %% [markdown]
# ## CLASSICAL CNN with the same number of parameters of the QCNN

# %%
def create_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, [3,3], activation='relu', input_shape=(8,8,1)))
    model.add(tf.keras.layers.Conv2D(64, [3,3], activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 6, 6, 32)          320
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 64)          18496
#
#  max_pooling2d_1 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 64)          0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 51,841
# Trainable params: 51,841
# Non-trainable params: 0
# _________________________________________________________________

# %%
notfair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=1,
          validation_data=(x_test_small, y_test))

cnn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 10ms/step - loss: 0.3289 - accuracy: 0.8126 - val_loss: 0.0890 - val_accuracy: 0.9620
# Epoch 2/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 0.9802 - val_loss: 0.0424 - val_accuracy: 0.9820
# Epoch 3/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0361 - accuracy: 0.9868 - val_loss: 0.0261 - val_accuracy: 0.9920
# Epoch 4/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0267 - accuracy: 0.9900 - val_loss: 0.0184 - val_accuracy: 0.9960
# Epoch 5/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 0.9926 - val_loss: 0.0115 - val_accuracy: 0.9980
# Epoch 6/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 0.9946 - val_loss: 0.0108 - val_accuracy: 0.9980
# Epoch 7/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.0109 - val_accuracy: 0.9980
# Epoch 8/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9948 - val_loss: 0.0107 - val_accuracy: 0.9980
# Epoch 9/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0078 - val_accuracy: 0.9960
# Epoch 10/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9964 - val_loss: 0.0080 - val_accuracy: 0.9980
# Epoch 11/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 0.9964 - val_loss: 0.0078 - val_accuracy: 0.9980
# Epoch 12/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0100 - val_accuracy: 0.9980
# Epoch 13/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9962 - val_loss: 0.0155 - val_accuracy: 0.9940
# Epoch 14/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9962 - val_loss: 0.0068 - val_accuracy: 0.9980
# Epoch 15/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0072 - val_accuracy: 0.9980
# Epoch 16/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0055 - val_accuracy: 0.9980
# Epoch 17/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 18/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.0087 - val_accuracy: 0.9980
# Epoch 19/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 20/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0099 - val_accuracy: 0.9980
# Epoch 21/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0045 - val_accuracy: 0.9980
# Epoch 22/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0054 - val_accuracy: 0.9980
# Epoch 23/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 0.0273 - val_accuracy: 0.9940
# Epoch 24/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0082 - val_accuracy: 0.9980
# Epoch 25/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0067 - val_accuracy: 0.9980
# Epoch 26/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0057 - val_accuracy: 0.9980
# Epoch 27/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0088 - val_accuracy: 0.9980
# Epoch 28/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0099 - val_accuracy: 0.9960
# Epoch 29/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0085 - val_accuracy: 0.9980
# Epoch 30/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0106 - val_accuracy: 0.9980
# Epoch 31/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.0130 - val_accuracy: 0.9980
# Epoch 32/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9980
# Epoch 33/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0089 - val_accuracy: 0.9980
# Epoch 34/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0033 - val_accuracy: 0.9980
# Epoch 35/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 0.9986 - val_loss: 0.0241 - val_accuracy: 0.9940
# Epoch 36/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0096 - val_accuracy: 0.9980
# Epoch 37/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0057 - val_accuracy: 0.9980
# Epoch 38/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0114 - val_accuracy: 0.9980
# Epoch 39/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.0095 - val_accuracy: 0.9980
# Epoch 40/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.0034 - val_accuracy: 0.9980
# Epoch 41/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.0035 - val_accuracy: 0.9980
# Epoch 42/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9988 - val_loss: 0.0282 - val_accuracy: 0.9940
# Epoch 43/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0041 - val_accuracy: 0.9980
# Epoch 44/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9994 - val_loss: 0.0040 - val_accuracy: 0.9980
# Epoch 45/50
# 40/40 [==============================] - 0s 8ms/step - loss: 6.7796e-04 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9980
# Epoch 46/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0108 - val_accuracy: 0.9960
# Epoch 47/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0030 - val_accuracy: 0.9980
# Epoch 48/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 0.9960 - val_loss: 0.0112 - val_accuracy: 0.9980
# Epoch 49/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9982 - val_loss: 0.0110 - val_accuracy: 0.9980
# Epoch 50/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0146 - val_accuracy: 0.9980
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0146 - accuracy: 0.9980

# %%
def create_fair_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(8,8,1)))
    model.add(tf.keras.layers.Dense(1, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_fair_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_3 (Flatten)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 1)                 65
#
#  dense_7 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 67
# Trainable params: 67
# Non-trainable params: 0
# _________________________________________________________________

# %%
fair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=2,
          validation_data=(x_test_small, y_test))

fair_nn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 - 0s - loss: 0.6765 - accuracy: 0.4874 - val_loss: 0.6521 - val_accuracy: 0.4620 - 436ms/epoch - 11ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.6250 - accuracy: 0.4874 - val_loss: 0.6131 - val_accuracy: 0.4620 - 46ms/epoch - 1ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.5871 - accuracy: 0.4874 - val_loss: 0.5786 - val_accuracy: 0.4620 - 48ms/epoch - 1ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.5504 - accuracy: 0.4874 - val_loss: 0.5459 - val_accuracy: 0.4620 - 58ms/epoch - 1ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.5170 - accuracy: 0.4874 - val_loss: 0.5151 - val_accuracy: 0.4620 - 45ms/epoch - 1ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.4869 - accuracy: 0.4874 - val_loss: 0.4879 - val_accuracy: 0.4620 - 51ms/epoch - 1ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.4600 - accuracy: 0.4874 - val_loss: 0.4633 - val_accuracy: 0.4620 - 54ms/epoch - 1ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.4362 - accuracy: 0.4874 - val_loss: 0.4411 - val_accuracy: 0.4620 - 66ms/epoch - 2ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.4148 - accuracy: 0.4874 - val_loss: 0.4214 - val_accuracy: 0.4620 - 54ms/epoch - 1ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.3954 - accuracy: 0.4874 - val_loss: 0.4036 - val_accuracy: 0.4620 - 68ms/epoch - 2ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.3779 - accuracy: 0.4874 - val_loss: 0.3874 - val_accuracy: 0.4620 - 62ms/epoch - 2ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.3619 - accuracy: 0.4874 - val_loss: 0.3722 - val_accuracy: 0.4620 - 46ms/epoch - 1ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.3471 - accuracy: 0.8140 - val_loss: 0.3581 - val_accuracy: 0.8720 - 49ms/epoch - 1ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.3334 - accuracy: 0.8940 - val_loss: 0.3454 - val_accuracy: 0.8880 - 49ms/epoch - 1ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.3208 - accuracy: 0.9118 - val_loss: 0.3333 - val_accuracy: 0.9080 - 46ms/epoch - 1ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.3091 - accuracy: 0.9168 - val_loss: 0.3217 - val_accuracy: 0.9180 - 49ms/epoch - 1ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.2982 - accuracy: 0.9240 - val_loss: 0.3112 - val_accuracy: 0.9300 - 54ms/epoch - 1ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.2879 - accuracy: 0.9360 - val_loss: 0.3013 - val_accuracy: 0.9380 - 46ms/epoch - 1ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.2783 - accuracy: 0.9384 - val_loss: 0.2922 - val_accuracy: 0.9420 - 49ms/epoch - 1ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.2692 - accuracy: 0.9420 - val_loss: 0.2833 - val_accuracy: 0.9460 - 56ms/epoch - 1ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.2606 - accuracy: 0.9488 - val_loss: 0.2749 - val_accuracy: 0.9480 - 59ms/epoch - 1ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.2525 - accuracy: 0.9534 - val_loss: 0.2671 - val_accuracy: 0.9540 - 50ms/epoch - 1ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.2448 - accuracy: 0.9574 - val_loss: 0.2597 - val_accuracy: 0.9600 - 48ms/epoch - 1ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.2375 - accuracy: 0.9606 - val_loss: 0.2524 - val_accuracy: 0.9640 - 46ms/epoch - 1ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.2306 - accuracy: 0.9614 - val_loss: 0.2454 - val_accuracy: 0.9640 - 45ms/epoch - 1ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.2241 - accuracy: 0.9622 - val_loss: 0.2391 - val_accuracy: 0.9700 - 52ms/epoch - 1ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.2179 - accuracy: 0.9632 - val_loss: 0.2330 - val_accuracy: 0.9700 - 56ms/epoch - 1ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.2121 - accuracy: 0.9688 - val_loss: 0.2292 - val_accuracy: 0.9720 - 63ms/epoch - 2ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.2063 - accuracy: 0.9686 - val_loss: 0.2226 - val_accuracy: 0.9700 - 59ms/epoch - 1ms/step
# Epoch 30/50
# 40/40 - 0s - loss: 0.2009 - accuracy: 0.9690 - val_loss: 0.2171 - val_accuracy: 0.9700 - 54ms/epoch - 1ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.1958 - accuracy: 0.9684 - val_loss: 0.2115 - val_accuracy: 0.9700 - 53ms/epoch - 1ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.1908 - accuracy: 0.9698 - val_loss: 0.2068 - val_accuracy: 0.9720 - 52ms/epoch - 1ms/step
# Epoch 33/50
# 40/40 - 0s - loss: 0.1861 - accuracy: 0.9710 - val_loss: 0.2023 - val_accuracy: 0.9720 - 54ms/epoch - 1ms/step
# Epoch 34/50
# 40/40 - 0s - loss: 0.1815 - accuracy: 0.9710 - val_loss: 0.1975 - val_accuracy: 0.9720 - 50ms/epoch - 1ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.1772 - accuracy: 0.9726 - val_loss: 0.1934 - val_accuracy: 0.9740 - 50ms/epoch - 1ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.1730 - accuracy: 0.9736 - val_loss: 0.1891 - val_accuracy: 0.9740 - 55ms/epoch - 1ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.1690 - accuracy: 0.9744 - val_loss: 0.1854 - val_accuracy: 0.9780 - 52ms/epoch - 1ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.1652 - accuracy: 0.9746 - val_loss: 0.1813 - val_accuracy: 0.9760 - 51ms/epoch - 1ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.1615 - accuracy: 0.9748 - val_loss: 0.1776 - val_accuracy: 0.9800 - 49ms/epoch - 1ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.1579 - accuracy: 0.9748 - val_loss: 0.1737 - val_accuracy: 0.9780 - 50ms/epoch - 1ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.1545 - accuracy: 0.9750 - val_loss: 0.1703 - val_accuracy: 0.9820 - 50ms/epoch - 1ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.1512 - accuracy: 0.9760 - val_loss: 0.1673 - val_accuracy: 0.9840 - 52ms/epoch - 1ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.1480 - accuracy: 0.9760 - val_loss: 0.1635 - val_accuracy: 0.9840 - 57ms/epoch - 1ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.1450 - accuracy: 0.9766 - val_loss: 0.1606 - val_accuracy: 0.9840 - 49ms/epoch - 1ms/step
# Epoch 45/50
# 40/40 - 0s - loss: 0.1420 - accuracy: 0.9768 - val_loss: 0.1580 - val_accuracy: 0.9880 - 46ms/epoch - 1ms/step
# Epoch 46/50
# 40/40 - 0s - loss: 0.1392 - accuracy: 0.9786 - val_loss: 0.1558 - val_accuracy: 0.9880 - 45ms/epoch - 1ms/step
# Epoch 47/50
# 40/40 - 0s - loss: 0.1363 - accuracy: 0.9776 - val_loss: 0.1523 - val_accuracy: 0.9880 - 45ms/epoch - 1ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.1337 - accuracy: 0.9786 - val_loss: 0.1498 - val_accuracy: 0.9880 - 45ms/epoch - 1ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.1311 - accuracy: 0.9786 - val_loss: 0.1475 - val_accuracy: 0.9880 - 53ms/epoch - 1ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.1286 - accuracy: 0.9792 - val_loss: 0.1449 - val_accuracy: 0.9880 - 52ms/epoch - 1ms/step
# 16/16 [==============================] - 0s 814us/step - loss: 0.1449 - accuracy: 0.9880

# %%
plt.plot(fair_nn.history['val_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()


ll = np.loadtxt("3loss.txt")
vl = np.loadtxt("3val_loss.txt")


q = np.loadtxt("3val_acc.txt")[0:50]
c = fair_nn.history['val_accuracy']
cc = notfair_nn.history['val_accuracy']

qnn_accuracy = np.mean(q[30:])
cnn_accuracy = np.mean(cc[30:])
fair_nn_accuracy = np.mean(c[30:])

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(c,"-.", marker= "o", markersize=2, label = "Fair Classical model", color="green")
axLL.plot(q,"-.", marker= "x", markersize=3, label = "Quantum model", color="violet")
axLL.plot(cc,"-.", marker= "x", markersize=3, label = "Not-fair Classical model", color="orange")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Accuracy")
axLL.legend(loc = 'best')
axLL.set_title("Classical-Quantum comparison")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
l, b, h, w = .4, .4, .2, .45
ax3 = fig.add_axes([l, b, w, h])
plt.ylim(0.7, 1.1)
x = ["Quantum", "Not-fair \n Classical", "Fair Classical"]
y = [qnn_accuracy, cnn_accuracy, fair_nn_accuracy]
plt.bar(x,y, color=("violet","orange","green" ))
# Adding labels to each bar

for i in range(len(x)):
    plt.text(x[i], y[i], '{:.3f}'.format(y[i]), ha='center', va='bottom')

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(ll,"-.", marker= "o", markersize=2, label = "Training Loss", color="green")
axLL.plot(vl,"-.", marker= "x", markersize=3, label = "Validation Loss", color="violet")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Loss")
axLL.legend(loc = 'best')
axLL.set_title("Quantum model Loss function")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
