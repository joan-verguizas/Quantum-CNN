# %%
#libraries

import tensorflow as tf
import tensorflow_quantum as tfq
import cirq
import sympy
import numpy as np
#import seaborn as sns
import collections

# visualization tools
# %matplotlib inline
import matplotlib.pyplot as plt
from cirq.contrib.svg import SVGCircuit
# Out:
# 2023-07-07 15:41:11.881157: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-07-07 15:41:11.881186: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-07-07 15:41:16.333638: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-07-07 15:41:16.333715: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (marco-Lenovo-S340-15IWL): /proc/driver/nvidia/version does not exist
# 2023-07-07 15:41:16.334531: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Import the data

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# # Filter the 3 and 6 labels

# %%
def filter_36(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_36(x_train, y_train)
x_test, y_test = filter_36(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %%
print(y_train[0])

plt.imshow(x_train[0, :, :, 0])
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Rescale the image

# %%
x_train_small = tf.image.resize(x_train, (4,4)).numpy()
x_test_small = tf.image.resize(x_test, (4,4)).numpy()
x_train_small = x_train_small[0:5000]
x_test_small = x_test_small[0:500]
y_train = y_train[0:5000]
y_test = y_test[0:500]

# %%
print(y_train[0])

plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1)
plt.colorbar()
# Out:
# True

# %% [markdown]
# ## Classical Convolutional Neural Network

# %% [markdown]
# ## CLASSICAL CNN with the same number of parameters of the QCNN

# %%
def create_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Conv2D(32, [2, 2], activation='relu', input_shape=(4,4,1)))
    model.add(tf.keras.layers.Conv2D(64, [2, 2], activation='relu'))
    model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
    model.add(tf.keras.layers.Dropout(0.25))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 3, 3, 32)          160
#
#  conv2d_3 (Conv2D)           (None, 2, 2, 64)          8256
#
#  max_pooling2d (MaxPooling2D  (None, 1, 1, 64)         0
#  )
#
#  dropout (Dropout)           (None, 1, 1, 64)          0
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 16,865
# Trainable params: 16,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
notfair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=1,
          validation_data=(x_test_small, y_test))

cnn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 1s 6ms/step - loss: 0.5650 - accuracy: 0.6238 - val_loss: 0.3874 - val_accuracy: 0.7920
# Epoch 2/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.3105 - accuracy: 0.8648 - val_loss: 0.3177 - val_accuracy: 0.8740
# Epoch 3/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2678 - accuracy: 0.8900 - val_loss: 0.3064 - val_accuracy: 0.8840
# Epoch 4/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2639 - accuracy: 0.8952 - val_loss: 0.2940 - val_accuracy: 0.8820
# Epoch 5/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2463 - accuracy: 0.9016 - val_loss: 0.2904 - val_accuracy: 0.8880
# Epoch 6/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2365 - accuracy: 0.9078 - val_loss: 0.2814 - val_accuracy: 0.8820
# Epoch 7/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2310 - accuracy: 0.9056 - val_loss: 0.2810 - val_accuracy: 0.8880
# Epoch 8/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2254 - accuracy: 0.9088 - val_loss: 0.2730 - val_accuracy: 0.8940
# Epoch 9/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2212 - accuracy: 0.9154 - val_loss: 0.2689 - val_accuracy: 0.8960
# Epoch 10/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2134 - accuracy: 0.9106 - val_loss: 0.2674 - val_accuracy: 0.8980
# Epoch 11/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.2131 - accuracy: 0.9122 - val_loss: 0.2669 - val_accuracy: 0.8980
# Epoch 12/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2110 - accuracy: 0.9150 - val_loss: 0.2583 - val_accuracy: 0.8980
# Epoch 13/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2005 - accuracy: 0.9166 - val_loss: 0.2529 - val_accuracy: 0.9040
# Epoch 14/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.2002 - accuracy: 0.9212 - val_loss: 0.2514 - val_accuracy: 0.8980
# Epoch 15/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1950 - accuracy: 0.9242 - val_loss: 0.2527 - val_accuracy: 0.9040
# Epoch 16/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1973 - accuracy: 0.9168 - val_loss: 0.2498 - val_accuracy: 0.9020
# Epoch 17/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1946 - accuracy: 0.9224 - val_loss: 0.2559 - val_accuracy: 0.8880
# Epoch 18/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1955 - accuracy: 0.9154 - val_loss: 0.2426 - val_accuracy: 0.9040
# Epoch 19/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1835 - accuracy: 0.9234 - val_loss: 0.2378 - val_accuracy: 0.9100
# Epoch 20/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1859 - accuracy: 0.9226 - val_loss: 0.2426 - val_accuracy: 0.9060
# Epoch 21/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1835 - accuracy: 0.9258 - val_loss: 0.2411 - val_accuracy: 0.9080
# Epoch 22/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1865 - accuracy: 0.9236 - val_loss: 0.2274 - val_accuracy: 0.9180
# Epoch 23/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1800 - accuracy: 0.9232 - val_loss: 0.2351 - val_accuracy: 0.9080
# Epoch 24/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1776 - accuracy: 0.9248 - val_loss: 0.2338 - val_accuracy: 0.9160
# Epoch 25/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1802 - accuracy: 0.9258 - val_loss: 0.2340 - val_accuracy: 0.9040
# Epoch 26/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1775 - accuracy: 0.9290 - val_loss: 0.2310 - val_accuracy: 0.9100
# Epoch 27/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1724 - accuracy: 0.9274 - val_loss: 0.2309 - val_accuracy: 0.9160
# Epoch 28/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9252 - val_loss: 0.2315 - val_accuracy: 0.9140
# Epoch 29/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9240 - val_loss: 0.2287 - val_accuracy: 0.9080
# Epoch 30/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1802 - accuracy: 0.9222 - val_loss: 0.2268 - val_accuracy: 0.9120
# Epoch 31/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1768 - accuracy: 0.9264 - val_loss: 0.2339 - val_accuracy: 0.9080
# Epoch 32/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1738 - accuracy: 0.9292 - val_loss: 0.2216 - val_accuracy: 0.9260
# Epoch 33/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1712 - accuracy: 0.9268 - val_loss: 0.2270 - val_accuracy: 0.9160
# Epoch 34/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1693 - accuracy: 0.9314 - val_loss: 0.2324 - val_accuracy: 0.9160
# Epoch 35/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1698 - accuracy: 0.9284 - val_loss: 0.2244 - val_accuracy: 0.9220
# Epoch 36/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1703 - accuracy: 0.9294 - val_loss: 0.2267 - val_accuracy: 0.9200
# Epoch 37/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1661 - accuracy: 0.9304 - val_loss: 0.2301 - val_accuracy: 0.9220
# Epoch 38/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1667 - accuracy: 0.9324 - val_loss: 0.2317 - val_accuracy: 0.9240
# Epoch 39/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1700 - accuracy: 0.9272 - val_loss: 0.2234 - val_accuracy: 0.9220
# Epoch 40/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1636 - accuracy: 0.9318 - val_loss: 0.2190 - val_accuracy: 0.9220
# Epoch 41/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9298 - val_loss: 0.2247 - val_accuracy: 0.9220
# Epoch 42/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9302 - val_loss: 0.2185 - val_accuracy: 0.9300
# Epoch 43/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9326 - val_loss: 0.2216 - val_accuracy: 0.9200
# Epoch 44/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1616 - accuracy: 0.9328 - val_loss: 0.2204 - val_accuracy: 0.9260
# Epoch 45/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1645 - accuracy: 0.9298 - val_loss: 0.2241 - val_accuracy: 0.9280
# Epoch 46/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1659 - accuracy: 0.9320 - val_loss: 0.2220 - val_accuracy: 0.9280
# Epoch 47/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.9318 - val_loss: 0.2208 - val_accuracy: 0.9260
# Epoch 48/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1606 - accuracy: 0.9332 - val_loss: 0.2195 - val_accuracy: 0.9260
# Epoch 49/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1617 - accuracy: 0.9346 - val_loss: 0.2240 - val_accuracy: 0.9260
# Epoch 50/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.1554 - accuracy: 0.9334 - val_loss: 0.2199 - val_accuracy: 0.9320
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2199 - accuracy: 0.9320

# %%
def create_fair_classical_model():
    # A simple model based off LeNet from https://keras.io/examples/mnist_cnn/
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(4,4,1)))
    model.add(tf.keras.layers.Dense(8, activation='relu'))
    model.add(tf.keras.layers.Dense(1))
    return model


model = create_fair_classical_model()
model.compile(loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_4 (Flatten)         (None, 16)                0
#
#  dense_8 (Dense)             (None, 8)                 136
#
#  dense_9 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 145
# Trainable params: 145
# Non-trainable params: 0
# _________________________________________________________________

# %%
fair_nn = model.fit(x_train_small,
          y_train,
          batch_size=128,
          epochs=50,
          verbose=2,
          validation_data=(x_test_small, y_test))

fair_nn_results = model.evaluate(x_test_small, y_test)
# Out:
# Epoch 1/50
# 40/40 - 0s - loss: 0.7197 - accuracy: 0.4872 - val_loss: 0.7014 - val_accuracy: 0.4620 - 457ms/epoch - 11ms/step
# Epoch 2/50
# 40/40 - 0s - loss: 0.6805 - accuracy: 0.4876 - val_loss: 0.6611 - val_accuracy: 0.4620 - 48ms/epoch - 1ms/step
# Epoch 3/50
# 40/40 - 0s - loss: 0.6288 - accuracy: 0.4890 - val_loss: 0.6061 - val_accuracy: 0.4680 - 51ms/epoch - 1ms/step
# Epoch 4/50
# 40/40 - 0s - loss: 0.5595 - accuracy: 0.5086 - val_loss: 0.5398 - val_accuracy: 0.5460 - 58ms/epoch - 1ms/step
# Epoch 5/50
# 40/40 - 0s - loss: 0.4838 - accuracy: 0.6108 - val_loss: 0.4789 - val_accuracy: 0.6340 - 48ms/epoch - 1ms/step
# Epoch 6/50
# 40/40 - 0s - loss: 0.4194 - accuracy: 0.7404 - val_loss: 0.4317 - val_accuracy: 0.7060 - 61ms/epoch - 2ms/step
# Epoch 7/50
# 40/40 - 0s - loss: 0.3697 - accuracy: 0.8174 - val_loss: 0.3950 - val_accuracy: 0.7580 - 67ms/epoch - 2ms/step
# Epoch 8/50
# 40/40 - 0s - loss: 0.3309 - accuracy: 0.8578 - val_loss: 0.3652 - val_accuracy: 0.7800 - 57ms/epoch - 1ms/step
# Epoch 9/50
# 40/40 - 0s - loss: 0.2999 - accuracy: 0.8734 - val_loss: 0.3417 - val_accuracy: 0.7900 - 52ms/epoch - 1ms/step
# Epoch 10/50
# 40/40 - 0s - loss: 0.2754 - accuracy: 0.8896 - val_loss: 0.3225 - val_accuracy: 0.8160 - 51ms/epoch - 1ms/step
# Epoch 11/50
# 40/40 - 0s - loss: 0.2555 - accuracy: 0.8990 - val_loss: 0.3073 - val_accuracy: 0.8340 - 48ms/epoch - 1ms/step
# Epoch 12/50
# 40/40 - 0s - loss: 0.2392 - accuracy: 0.9048 - val_loss: 0.2944 - val_accuracy: 0.8500 - 55ms/epoch - 1ms/step
# Epoch 13/50
# 40/40 - 0s - loss: 0.2257 - accuracy: 0.9100 - val_loss: 0.2833 - val_accuracy: 0.8580 - 54ms/epoch - 1ms/step
# Epoch 14/50
# 40/40 - 0s - loss: 0.2144 - accuracy: 0.9126 - val_loss: 0.2745 - val_accuracy: 0.8680 - 50ms/epoch - 1ms/step
# Epoch 15/50
# 40/40 - 0s - loss: 0.2048 - accuracy: 0.9178 - val_loss: 0.2667 - val_accuracy: 0.8720 - 55ms/epoch - 1ms/step
# Epoch 16/50
# 40/40 - 0s - loss: 0.1964 - accuracy: 0.9266 - val_loss: 0.2588 - val_accuracy: 0.9140 - 64ms/epoch - 2ms/step
# Epoch 17/50
# 40/40 - 0s - loss: 0.1888 - accuracy: 0.9388 - val_loss: 0.2518 - val_accuracy: 0.9140 - 56ms/epoch - 1ms/step
# Epoch 18/50
# 40/40 - 0s - loss: 0.1806 - accuracy: 0.9398 - val_loss: 0.2450 - val_accuracy: 0.9120 - 54ms/epoch - 1ms/step
# Epoch 19/50
# 40/40 - 0s - loss: 0.1721 - accuracy: 0.9404 - val_loss: 0.2413 - val_accuracy: 0.9120 - 57ms/epoch - 1ms/step
# Epoch 20/50
# 40/40 - 0s - loss: 0.1661 - accuracy: 0.9412 - val_loss: 0.2400 - val_accuracy: 0.9120 - 60ms/epoch - 2ms/step
# Epoch 21/50
# 40/40 - 0s - loss: 0.1620 - accuracy: 0.9420 - val_loss: 0.2395 - val_accuracy: 0.9120 - 55ms/epoch - 1ms/step
# Epoch 22/50
# 40/40 - 0s - loss: 0.1592 - accuracy: 0.9418 - val_loss: 0.2396 - val_accuracy: 0.9120 - 54ms/epoch - 1ms/step
# Epoch 23/50
# 40/40 - 0s - loss: 0.1569 - accuracy: 0.9424 - val_loss: 0.2391 - val_accuracy: 0.9140 - 59ms/epoch - 1ms/step
# Epoch 24/50
# 40/40 - 0s - loss: 0.1554 - accuracy: 0.9420 - val_loss: 0.2388 - val_accuracy: 0.9160 - 50ms/epoch - 1ms/step
# Epoch 25/50
# 40/40 - 0s - loss: 0.1543 - accuracy: 0.9414 - val_loss: 0.2378 - val_accuracy: 0.9160 - 49ms/epoch - 1ms/step
# Epoch 26/50
# 40/40 - 0s - loss: 0.1532 - accuracy: 0.9430 - val_loss: 0.2377 - val_accuracy: 0.9160 - 55ms/epoch - 1ms/step
# Epoch 27/50
# 40/40 - 0s - loss: 0.1523 - accuracy: 0.9424 - val_loss: 0.2379 - val_accuracy: 0.9200 - 56ms/epoch - 1ms/step
# Epoch 28/50
# 40/40 - 0s - loss: 0.1515 - accuracy: 0.9424 - val_loss: 0.2378 - val_accuracy: 0.9200 - 58ms/epoch - 1ms/step
# Epoch 29/50
# 40/40 - 0s - loss: 0.1510 - accuracy: 0.9418 - val_loss: 0.2383 - val_accuracy: 0.9240 - 60ms/epoch - 1ms/step
# Epoch 30/50
# 40/40 - 0s - loss: 0.1503 - accuracy: 0.9430 - val_loss: 0.2382 - val_accuracy: 0.9220 - 51ms/epoch - 1ms/step
# Epoch 31/50
# 40/40 - 0s - loss: 0.1499 - accuracy: 0.9434 - val_loss: 0.2382 - val_accuracy: 0.9220 - 54ms/epoch - 1ms/step
# Epoch 32/50
# 40/40 - 0s - loss: 0.1495 - accuracy: 0.9436 - val_loss: 0.2385 - val_accuracy: 0.9220 - 59ms/epoch - 1ms/step
# Epoch 33/50
# 40/40 - 0s - loss: 0.1489 - accuracy: 0.9432 - val_loss: 0.2382 - val_accuracy: 0.9240 - 54ms/epoch - 1ms/step
# Epoch 34/50
# 40/40 - 0s - loss: 0.1485 - accuracy: 0.9428 - val_loss: 0.2381 - val_accuracy: 0.9220 - 53ms/epoch - 1ms/step
# Epoch 35/50
# 40/40 - 0s - loss: 0.1481 - accuracy: 0.9434 - val_loss: 0.2381 - val_accuracy: 0.9220 - 55ms/epoch - 1ms/step
# Epoch 36/50
# 40/40 - 0s - loss: 0.1479 - accuracy: 0.9442 - val_loss: 0.2377 - val_accuracy: 0.9240 - 54ms/epoch - 1ms/step
# Epoch 37/50
# 40/40 - 0s - loss: 0.1477 - accuracy: 0.9436 - val_loss: 0.2381 - val_accuracy: 0.9240 - 59ms/epoch - 1ms/step
# Epoch 38/50
# 40/40 - 0s - loss: 0.1473 - accuracy: 0.9436 - val_loss: 0.2380 - val_accuracy: 0.9240 - 55ms/epoch - 1ms/step
# Epoch 39/50
# 40/40 - 0s - loss: 0.1471 - accuracy: 0.9438 - val_loss: 0.2377 - val_accuracy: 0.9240 - 57ms/epoch - 1ms/step
# Epoch 40/50
# 40/40 - 0s - loss: 0.1469 - accuracy: 0.9440 - val_loss: 0.2374 - val_accuracy: 0.9220 - 53ms/epoch - 1ms/step
# Epoch 41/50
# 40/40 - 0s - loss: 0.1466 - accuracy: 0.9436 - val_loss: 0.2371 - val_accuracy: 0.9240 - 55ms/epoch - 1ms/step
# Epoch 42/50
# 40/40 - 0s - loss: 0.1465 - accuracy: 0.9444 - val_loss: 0.2363 - val_accuracy: 0.9240 - 52ms/epoch - 1ms/step
# Epoch 43/50
# 40/40 - 0s - loss: 0.1462 - accuracy: 0.9446 - val_loss: 0.2363 - val_accuracy: 0.9220 - 49ms/epoch - 1ms/step
# Epoch 44/50
# 40/40 - 0s - loss: 0.1459 - accuracy: 0.9440 - val_loss: 0.2361 - val_accuracy: 0.9240 - 53ms/epoch - 1ms/step
# Epoch 45/50
# 40/40 - 0s - loss: 0.1460 - accuracy: 0.9446 - val_loss: 0.2364 - val_accuracy: 0.9240 - 59ms/epoch - 1ms/step
# Epoch 46/50
# 40/40 - 0s - loss: 0.1459 - accuracy: 0.9452 - val_loss: 0.2365 - val_accuracy: 0.9220 - 60ms/epoch - 2ms/step
# Epoch 47/50
# 40/40 - 0s - loss: 0.1455 - accuracy: 0.9438 - val_loss: 0.2360 - val_accuracy: 0.9220 - 64ms/epoch - 2ms/step
# Epoch 48/50
# 40/40 - 0s - loss: 0.1454 - accuracy: 0.9452 - val_loss: 0.2364 - val_accuracy: 0.9220 - 59ms/epoch - 1ms/step
# Epoch 49/50
# 40/40 - 0s - loss: 0.1453 - accuracy: 0.9450 - val_loss: 0.2360 - val_accuracy: 0.9220 - 58ms/epoch - 1ms/step
# Epoch 50/50
# 40/40 - 0s - loss: 0.1450 - accuracy: 0.9442 - val_loss: 0.2359 - val_accuracy: 0.9220 - 47ms/epoch - 1ms/step
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2359 - accuracy: 0.9220

# %%
plt.plot(fair_nn.history['val_accuracy'], label='QCNN')
plt.title('Quantum vs Hybrid CNN performance')
plt.xlabel('Epochs')
plt.legend()
plt.ylabel('Validation Accuracy')
plt.show()


ll = np.loadtxt("2loss.txt")
vl = np.loadtxt("2val_loss.txt")


q = np.loadtxt("2val_acc.txt")
c = fair_nn.history['val_accuracy']
cc = notfair_nn.history['val_accuracy']

qnn_accuracy = np.mean(q[30:])
cnn_accuracy = np.mean(cc[30:])
fair_nn_accuracy = np.mean(c[30:])

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(c,"-.", marker= "o", markersize=2, label = "Fair Classical model", color="green")
axLL.plot(q,"-.", marker= "x", markersize=3, label = "Quantum model", color="violet")
axLL.plot(cc,"-.", marker= "x", markersize=3, label = "Not-fair Classical model", color="orange")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Accuracy")
axLL.legend(loc = 'best')
axLL.set_title("Classical-Quantum comparison")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
l, b, h, w = .4, .4, .2, .45
ax3 = fig.add_axes([l, b, w, h])
plt.ylim(0.7, 1.1)
x = ["Quantum", "Not-fair \n Classical", "Fair Classical"]
y = [qnn_accuracy, cnn_accuracy, fair_nn_accuracy]
plt.bar(x,y, color=("violet","orange","green" ))
# Adding labels to each bar

for i in range(len(x)):
    plt.text(x[i], y[i], '{:.3f}'.format(y[i]), ha='center', va='bottom')

# %%
fig, axLL = plt.subplots(1, 1 , figsize=(6, 6))


axLL.plot(ll,"-.", marker= "o", markersize=2, label = "Training Loss", color="green")
axLL.plot(vl,"-.", marker= "x", markersize=3, label = "Validation Loss", color="violet")

axLL.set_xlabel("epochs")
axLL.set_ylabel("Loss")
axLL.legend(loc = 'best')
axLL.set_title("Quantum model Loss function")
#axLL.set_ylim(-5.7,-5.1)
#plt.ylim(-0.2,0.1)
axLL.grid(True, which= "both")
